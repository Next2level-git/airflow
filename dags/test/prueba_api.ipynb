# %%
import json
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/fixtures"

querystring = {"league":"239","season":"2024"}

headers = {
	"x-rapidapi-key": "5ada26f90cmsh42c7290dd83d724p1f721cjsn4b0c4acc71b9",
	"x-rapidapi-host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
data = response.json()
filtered_response = [item for item in data['response'] if item['fixture']['status']['short'] == 'FT']
print(filtered_response)
# Out:
# [{'fixture': {'id': 1153061, 'referee': 'Edwin Ferney Trujillo Castro, Colombia', 'timezone': 'UTC', 'date': '2024-01-20T23:10:00+00:00', 'timestamp': 1705792200, 'periods': {'first': 1705792200, 'second': 1705795800}, 'venue': {'id': 375, 'name': 'Estadio Manuel Murillo Toro', 'city': 'Ibagué'}, 'status': {'long': 'Match Finished', 'short': 'FT', 'elapsed': 90}}, 'league': {'id': 239, 'name': 'Primera A', 'country': 'Colombia', 'logo': 'https://media.api-sports.io/football/leagues/239.png', 'flag': 'https://media.api-sports.io/flags/co.svg', 'season': 2024, 'round': 'Apertura - 1'}, 'teams': {'home': {'id': 1142, 'name': 'Deportes Tolima', 'logo': 'https://media.api-sports.io/football/teams/1142.png', 'winner': False}, 'away': {'id': 1147, 'name': 'Fortaleza FC', 'logo': 'https://media.api-sports.io/football/teams/1147.png', 'winner': True}}, 'goals': {'home': 1, 'away': 2}, 'score': {'halftime': {'home': 0, 'away': 1}, 'fulltime': {'home': 1, 'away': 2}, 'extratime': {'home': None,
# ...

# %%
import pandas as pd


df = pd.DataFrame(filtered_response)

# %%
df_home_team = pd.DataFrame(df['teams'].apply(lambda x: x['home']).tolist())
df_home_team = df_home_team[['id', 'name']]

# %%
df_away_team = pd.DataFrame(df['teams'].apply(lambda x: x['away']).tolist())
df_away_team = df_home_team[['id', 'name']]
